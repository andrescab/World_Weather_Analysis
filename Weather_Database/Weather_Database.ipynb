# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a new set of 2000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
#Get the nearest city using the citipy module.
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
   
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 787

# %%
# Perform and API call with OpenWeatherMap 
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
import time
from datetime import datetime

# %%
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pontal do parana
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 4 of Set 1 | katsuura
# Processing Record 5 of Set 1 | margate
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | torbay
# Processing Record 8 of Set 1 | sao domingos do maranhao
# Processing Record 9 of Set 1 | oranjestad
# Processing Record 10 of Set 1 | namatanai
# Processing Record 11 of Set 1 | moron
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | florestopolis
# Processing Record 14 of Set 1 | antofagasta
# Processing Record 15 of Set 1 | roros
# Processing Record 16 of Set 1 | maxixe
# Processing Record 17 of Set 1 | chuguyevka
# Processing Record 18 of Set 1 | kaitangata
# Processing Record 19 of Set 1 | east london
# Processing Record 20 of Set 1 | nakonde
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | kapaa
# Processing Record 26 of Set 1 | lebu
# Processing Record 27 of Set 1 | mollendo
# Processing Record 28 of Set 1 | latung
# Processing Record 29 of Set 1 | hilo
# Processing Record 30 of Set 1 | usinsk
# Processing Record 31 of Set 1 | tessalit
# Processing Record 32 of Set 1 | bensonville
# Processing Record 33 of Set 1 | korla
# Processing Record 34 of Set 1 | andradina
# Processing Record 35 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 1 | karema
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | simao
# Processing Record 39 of Set 1 | visby
# Processing Record 40 of Set 1 | itarema
# Processing Record 41 of Set 1 | silver city
# Processing Record 42 of Set 1 | esperance
# Processing Record 43 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 1 | saint-francois
# Processing Record 45 of Set 1 | sarakhs
# Processing Record 46 of Set 1 | berlevag
# Processing Record 47 of Set 1 | new norfolk
# Processing Record 48 of Set 1 | fairbanks
# Processing Record 49 of Set 1 | waw
# Processing Record 50 of Set 1 | busselton
# Processing Record 1 of Set 2 | bredasdorp
# Processing Record 2 of Set 2 | moranbah
# Processing Record 3 of Set 2 | bambous virieux
# Processing Record 4 of Set 2 | vostok
# Processing Record 5 of Set 2 | san quintin
# Processing Record 6 of Set 2 | arraial do cabo
# Processing Record 7 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 2 | san cristobal
# Processing Record 9 of Set 2 | tuatapere
# Processing Record 10 of Set 2 | zabaykalsk
# Processing Record 11 of Set 2 | port alfred
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | saldanha
# Processing Record 14 of Set 2 | cabo san lucas
# Processing Record 15 of Set 2 | ambodifototra
# City not found. Skipping...
# Processing Record 16 of Set 2 | aykhal
# Processing Record 17 of Set 2 | puerto ayora
# Processing Record 18 of Set 2 | syracuse
# Processing Record 19 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 2 | vila franca do campo
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | talnakh
# Processing Record 23 of Set 2 | jamestown
# Processing Record 24 of Set 2 | longyearbyen
# Processing Record 25 of Set 2 | punta arenas
# Processing Record 26 of Set 2 | anadyr
# Processing Record 27 of Set 2 | boyolangu
# Processing Record 28 of Set 2 | mar del plata
# Processing Record 29 of Set 2 | isangel
# Processing Record 30 of Set 2 | anchorage
# Processing Record 31 of Set 2 | haines junction
# Processing Record 32 of Set 2 | ardatov
# Processing Record 33 of Set 2 | ribeira grande
# Processing Record 34 of Set 2 | yar-sale
# Processing Record 35 of Set 2 | hobart
# Processing Record 36 of Set 2 | nikolskoye
# Processing Record 37 of Set 2 | chokurdakh
# Processing Record 38 of Set 2 | tuktoyaktuk
# Processing Record 39 of Set 2 | bengkulu
# Processing Record 40 of Set 2 | dikson
# Processing Record 41 of Set 2 | ocean springs
# Processing Record 42 of Set 2 | coahuayana
# Processing Record 43 of Set 2 | urubamba
# Processing Record 44 of Set 2 | candawaga
# City not found. Skipping...
# Processing Record 45 of Set 2 | khatanga
# Processing Record 46 of Set 2 | georgetown
# Processing Record 47 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 2 | paamiut
# Processing Record 49 of Set 2 | keti bandar
# Processing Record 50 of Set 2 | mount gambier
# Processing Record 1 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 3 | riberalta
# Processing Record 3 of Set 3 | avarua
# Processing Record 4 of Set 3 | yovon
# Processing Record 5 of Set 3 | barrow
# Processing Record 6 of Set 3 | clyde river
# Processing Record 7 of Set 3 | severo-kurilsk
# Processing Record 8 of Set 3 | dingli
# Processing Record 9 of Set 3 | gornyy
# Processing Record 10 of Set 3 | beyneu
# Processing Record 11 of Set 3 | namibe
# Processing Record 12 of Set 3 | lompoc
# Processing Record 13 of Set 3 | saint-philippe
# Processing Record 14 of Set 3 | vanimo
# Processing Record 15 of Set 3 | inta
# Processing Record 16 of Set 3 | airai
# Processing Record 17 of Set 3 | mahebourg
# Processing Record 18 of Set 3 | grindavik
# Processing Record 19 of Set 3 | carnarvon
# Processing Record 20 of Set 3 | ponta do sol
# Processing Record 21 of Set 3 | benque viejo
# City not found. Skipping...
# Processing Record 22 of Set 3 | qaanaaq
# Processing Record 23 of Set 3 | baruun-urt
# Processing Record 24 of Set 3 | chuy
# Processing Record 25 of Set 3 | lakes entrance
# Processing Record 26 of Set 3 | dingle
# Processing Record 27 of Set 3 | waipawa
# Processing Record 28 of Set 3 | cockburn town
# Processing Record 29 of Set 3 | bonneville
# Processing Record 30 of Set 3 | salalah
# Processing Record 31 of Set 3 | nemuro
# Processing Record 32 of Set 3 | san patricio
# Processing Record 33 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 3 | vulcan
# Processing Record 35 of Set 3 | bandarbeyla
# Processing Record 36 of Set 3 | derzhavinsk
# Processing Record 37 of Set 3 | binodegahan
# Processing Record 38 of Set 3 | abu samrah
# Processing Record 39 of Set 3 | qandahar
# City not found. Skipping...
# Processing Record 40 of Set 3 | dvinskoy
# Processing Record 41 of Set 3 | liverpool
# Processing Record 42 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 43 of Set 3 | fukue
# Processing Record 44 of Set 3 | havoysund
# Processing Record 45 of Set 3 | solsvik
# City not found. Skipping...
# Processing Record 46 of Set 3 | marzuq
# Processing Record 47 of Set 3 | xining
# Processing Record 48 of Set 3 | aswan
# Processing Record 49 of Set 3 | xai-xai
# Processing Record 50 of Set 3 | pevek
# Processing Record 1 of Set 4 | cantaura
# Processing Record 2 of Set 4 | santa isabel
# Processing Record 3 of Set 4 | great falls
# Processing Record 4 of Set 4 | upernavik
# Processing Record 5 of Set 4 | hithadhoo
# Processing Record 6 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 4 | saskylakh
# Processing Record 8 of Set 4 | port hedland
# Processing Record 9 of Set 4 | ahipara
# Processing Record 10 of Set 4 | punta alta
# Processing Record 11 of Set 4 | tarbes
# Processing Record 12 of Set 4 | fuerte olimpo
# Processing Record 13 of Set 4 | buala
# Processing Record 14 of Set 4 | norman wells
# Processing Record 15 of Set 4 | yeppoon
# Processing Record 16 of Set 4 | thompson
# Processing Record 17 of Set 4 | castro
# Processing Record 18 of Set 4 | kayerkan
# Processing Record 19 of Set 4 | moose factory
# Processing Record 20 of Set 4 | hesperia
# Processing Record 21 of Set 4 | malinovoye ozero
# Processing Record 22 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 4 | cherskiy
# Processing Record 24 of Set 4 | mount isa
# Processing Record 25 of Set 4 | monterey
# Processing Record 26 of Set 4 | berezovyy
# Processing Record 27 of Set 4 | kovdor
# Processing Record 28 of Set 4 | quatre cocos
# Processing Record 29 of Set 4 | llangefni
# Processing Record 30 of Set 4 | mixtepec
# City not found. Skipping...
# Processing Record 31 of Set 4 | palm valley
# Processing Record 32 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 4 | saint george
# Processing Record 35 of Set 4 | shellbrook
# Processing Record 36 of Set 4 | mehamn
# Processing Record 37 of Set 4 | batemans bay
# Processing Record 38 of Set 4 | stavern
# Processing Record 39 of Set 4 | chiredzi
# Processing Record 40 of Set 4 | cockburn harbour
# City not found. Skipping...
# Processing Record 41 of Set 4 | auki
# Processing Record 42 of Set 4 | san-pedro
# Processing Record 43 of Set 4 | piacabucu
# Processing Record 44 of Set 4 | yumen
# Processing Record 45 of Set 4 | touros
# Processing Record 46 of Set 4 | kalmunai
# Processing Record 47 of Set 4 | vila velha
# Processing Record 48 of Set 4 | ust-nera
# Processing Record 49 of Set 4 | manokwari
# Processing Record 50 of Set 4 | nha trang
# Processing Record 1 of Set 5 | kahului
# Processing Record 2 of Set 5 | zheleznodorozhnyy
# Processing Record 3 of Set 5 | bethel
# Processing Record 4 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 5 | bonavista
# Processing Record 6 of Set 5 | flinders
# Processing Record 7 of Set 5 | taltal
# Processing Record 8 of Set 5 | cidreira
# Processing Record 9 of Set 5 | chicla
# Processing Record 10 of Set 5 | tasiilaq
# Processing Record 11 of Set 5 | xingyi
# Processing Record 12 of Set 5 | hopelchen
# Processing Record 13 of Set 5 | alice springs
# Processing Record 14 of Set 5 | omsukchan
# Processing Record 15 of Set 5 | aloleng
# Processing Record 16 of Set 5 | lata
# Processing Record 17 of Set 5 | manicore
# Processing Record 18 of Set 5 | dauphin
# Processing Record 19 of Set 5 | mumford
# Processing Record 20 of Set 5 | zhigansk
# Processing Record 21 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 5 | leningradskiy
# Processing Record 23 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 24 of Set 5 | biak
# Processing Record 25 of Set 5 | baft
# Processing Record 26 of Set 5 | manta
# Processing Record 27 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 5 | tamandare
# Processing Record 29 of Set 5 | half moon bay
# Processing Record 30 of Set 5 | port hardy
# Processing Record 31 of Set 5 | ranau
# Processing Record 32 of Set 5 | ancud
# Processing Record 33 of Set 5 | port blair
# Processing Record 34 of Set 5 | zaoyang
# Processing Record 35 of Set 5 | songjianghe
# Processing Record 36 of Set 5 | arman
# Processing Record 37 of Set 5 | urucui
# Processing Record 38 of Set 5 | leh
# Processing Record 39 of Set 5 | verkh-usugli
# Processing Record 40 of Set 5 | boa vista
# Processing Record 41 of Set 5 | axim
# Processing Record 42 of Set 5 | ostrovnoy
# Processing Record 43 of Set 5 | maneadero
# Processing Record 44 of Set 5 | elko
# Processing Record 45 of Set 5 | rawson
# Processing Record 46 of Set 5 | norrkoping
# Processing Record 47 of Set 5 | tumut
# Processing Record 48 of Set 5 | monroe
# Processing Record 49 of Set 5 | alausi
# Processing Record 50 of Set 5 | zhezkazgan
# Processing Record 1 of Set 6 | olafsvik
# Processing Record 2 of Set 6 | george town
# Processing Record 3 of Set 6 | awbari
# Processing Record 4 of Set 6 | ravar
# Processing Record 5 of Set 6 | kavieng
# Processing Record 6 of Set 6 | luderitz
# Processing Record 7 of Set 6 | codrington
# Processing Record 8 of Set 6 | vardo
# Processing Record 9 of Set 6 | salamanca
# Processing Record 10 of Set 6 | rosa zarate
# Processing Record 11 of Set 6 | atasu
# Processing Record 12 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 6 | batagay-alyta
# Processing Record 14 of Set 6 | mareeba
# Processing Record 15 of Set 6 | jaisalmer
# Processing Record 16 of Set 6 | sailana
# Processing Record 17 of Set 6 | sosnovo-ozerskoye
# Processing Record 18 of Set 6 | ishinomaki
# Processing Record 19 of Set 6 | kodiak
# Processing Record 20 of Set 6 | victor harbor
# Processing Record 21 of Set 6 | tateyama
# Processing Record 22 of Set 6 | mundo nuevo
# Processing Record 23 of Set 6 | port-cartier
# Processing Record 24 of Set 6 | shenjiamen
# Processing Record 25 of Set 6 | victoria
# Processing Record 26 of Set 6 | gedo
# Processing Record 27 of Set 6 | fonte boa
# Processing Record 28 of Set 6 | provideniya
# Processing Record 29 of Set 6 | ilulissat
# Processing Record 30 of Set 6 | mindelo
# Processing Record 31 of Set 6 | cayenne
# Processing Record 32 of Set 6 | muros
# Processing Record 33 of Set 6 | gboko
# Processing Record 34 of Set 6 | gazojak
# Processing Record 35 of Set 6 | port elizabeth
# Processing Record 36 of Set 6 | miri
# Processing Record 37 of Set 6 | castelo do piaui
# Processing Record 38 of Set 6 | rhyl
# Processing Record 39 of Set 6 | bratsk
# Processing Record 40 of Set 6 | raudeberg
# Processing Record 41 of Set 6 | ritchie
# Processing Record 42 of Set 6 | live oak
# Processing Record 43 of Set 6 | la ronge
# Processing Record 44 of Set 6 | havelock
# Processing Record 45 of Set 6 | pampas
# Processing Record 46 of Set 6 | geraldton
# Processing Record 47 of Set 6 | cananea
# Processing Record 48 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 6 | bontang
# Processing Record 50 of Set 6 | aiani
# Processing Record 1 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 2 of Set 7 | yellowknife
# Processing Record 3 of Set 7 | fruitville
# Processing Record 4 of Set 7 | hasaki
# Processing Record 5 of Set 7 | kununurra
# Processing Record 6 of Set 7 | monte siao
# Processing Record 7 of Set 7 | soyo
# Processing Record 8 of Set 7 | aripuana
# Processing Record 9 of Set 7 | devonport
# Processing Record 10 of Set 7 | panjab
# Processing Record 11 of Set 7 | chapais
# Processing Record 12 of Set 7 | yilan
# Processing Record 13 of Set 7 | nevelsk
# Processing Record 14 of Set 7 | pangnirtung
# Processing Record 15 of Set 7 | porto-vecchio
# Processing Record 16 of Set 7 | homer
# Processing Record 17 of Set 7 | wilmington
# Processing Record 18 of Set 7 | phillipsburg
# Processing Record 19 of Set 7 | juifang
# City not found. Skipping...
# Processing Record 20 of Set 7 | manoharpur
# Processing Record 21 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 22 of Set 7 | mineros
# Processing Record 23 of Set 7 | jacareacanga
# Processing Record 24 of Set 7 | vorobyevka
# Processing Record 25 of Set 7 | fortuna
# Processing Record 26 of Set 7 | nome
# Processing Record 27 of Set 7 | saint-georges
# Processing Record 28 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 7 | acajutla
# Processing Record 30 of Set 7 | husavik
# Processing Record 31 of Set 7 | tingi
# Processing Record 32 of Set 7 | comodoro rivadavia
# Processing Record 33 of Set 7 | ulladulla
# Processing Record 34 of Set 7 | samarai
# Processing Record 35 of Set 7 | vestmannaeyjar
# Processing Record 36 of Set 7 | mocambique
# City not found. Skipping...
# Processing Record 37 of Set 7 | macaboboni
# City not found. Skipping...
# Processing Record 38 of Set 7 | waitara
# Processing Record 39 of Set 7 | iqaluit
# Processing Record 40 of Set 7 | iquique
# Processing Record 41 of Set 7 | beringovskiy
# Processing Record 42 of Set 7 | klaksvik
# Processing Record 43 of Set 7 | coos bay
# Processing Record 44 of Set 7 | patacamaya
# Processing Record 45 of Set 7 | salihli
# Processing Record 46 of Set 7 | hammerfest
# Processing Record 47 of Set 7 | carballo
# Processing Record 48 of Set 7 | devarkonda
# Processing Record 49 of Set 7 | kitimat
# Processing Record 50 of Set 7 | khawhai
# Processing Record 1 of Set 8 | venado tuerto
# Processing Record 2 of Set 8 | kodinar
# Processing Record 3 of Set 8 | los llanos de aridane
# Processing Record 4 of Set 8 | lagoa
# Processing Record 5 of Set 8 | bathsheba
# Processing Record 6 of Set 8 | arlit
# Processing Record 7 of Set 8 | nerchinskiy zavod
# Processing Record 8 of Set 8 | faanui
# Processing Record 9 of Set 8 | nandigama
# Processing Record 10 of Set 8 | kruisfontein
# Processing Record 11 of Set 8 | road town
# Processing Record 12 of Set 8 | dudinka
# Processing Record 13 of Set 8 | dong hoi
# Processing Record 14 of Set 8 | matamba
# Processing Record 15 of Set 8 | iwanai
# Processing Record 16 of Set 8 | mittersill
# Processing Record 17 of Set 8 | baturaja
# Processing Record 18 of Set 8 | melo
# Processing Record 19 of Set 8 | madingou
# Processing Record 20 of Set 8 | puerto montt
# Processing Record 21 of Set 8 | kungurtug
# Processing Record 22 of Set 8 | birjand
# Processing Record 23 of Set 8 | faya
# Processing Record 24 of Set 8 | necochea
# Processing Record 25 of Set 8 | acapulco
# Processing Record 26 of Set 8 | colares
# Processing Record 27 of Set 8 | nabire
# Processing Record 28 of Set 8 | zyuzelskiy
# Processing Record 29 of Set 8 | noyabrsk
# Processing Record 30 of Set 8 | turayf
# Processing Record 31 of Set 8 | zeya
# Processing Record 32 of Set 8 | pombas
# Processing Record 33 of Set 8 | saint-pierre
# Processing Record 34 of Set 8 | uusikaupunki
# Processing Record 35 of Set 8 | constitucion
# Processing Record 36 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 37 of Set 8 | blyth
# Processing Record 38 of Set 8 | inhambane
# Processing Record 39 of Set 8 | rio grande
# Processing Record 40 of Set 8 | ko samui
# Processing Record 41 of Set 8 | mayna
# Processing Record 42 of Set 8 | smithers
# Processing Record 43 of Set 8 | barra do garcas
# Processing Record 44 of Set 8 | novyy urengoy
# Processing Record 45 of Set 8 | kloulklubed
# Processing Record 46 of Set 8 | ivanteyevka
# Processing Record 47 of Set 8 | port keats
# Processing Record 48 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 50 of Set 8 | pauini
# Processing Record 1 of Set 9 | igurubi
# Processing Record 2 of Set 9 | mae sot
# Processing Record 3 of Set 9 | tual
# Processing Record 4 of Set 9 | charters towers
# Processing Record 5 of Set 9 | rio gallegos
# Processing Record 6 of Set 9 | marabba
# Processing Record 7 of Set 9 | fort nelson
# Processing Record 8 of Set 9 | whyalla
# Processing Record 9 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 10 of Set 9 | viseu
# Processing Record 11 of Set 9 | sringeri
# Processing Record 12 of Set 9 | lavrentiya
# Processing Record 13 of Set 9 | tawang
# Processing Record 14 of Set 9 | gilgit
# Processing Record 15 of Set 9 | hualmay
# Processing Record 16 of Set 9 | sokolo
# Processing Record 17 of Set 9 | meulaboh
# Processing Record 18 of Set 9 | san marcos de colon
# Processing Record 19 of Set 9 | huarmey
# Processing Record 20 of Set 9 | nanortalik
# Processing Record 21 of Set 9 | sao joao da barra
# Processing Record 22 of Set 9 | balkanabat
# Processing Record 23 of Set 9 | vao
# Processing Record 24 of Set 9 | tayzhina
# Processing Record 25 of Set 9 | hambantota
# Processing Record 26 of Set 9 | ocampo
# Processing Record 27 of Set 9 | witu
# Processing Record 28 of Set 9 | paita
# Processing Record 29 of Set 9 | cabedelo
# Processing Record 30 of Set 9 | oktyabrskiy
# Processing Record 31 of Set 9 | lichinga
# Processing Record 32 of Set 9 | mackay
# Processing Record 33 of Set 9 | saint anthony
# Processing Record 34 of Set 9 | marystown
# Processing Record 35 of Set 9 | bayan
# Processing Record 36 of Set 9 | ayan
# Processing Record 37 of Set 9 | yabrud
# Processing Record 38 of Set 9 | sibu
# Processing Record 39 of Set 9 | yangjiang
# Processing Record 40 of Set 9 | ixtapa
# Processing Record 41 of Set 9 | mgachi
# Processing Record 42 of Set 9 | foca
# Processing Record 43 of Set 9 | zhenjiang
# Processing Record 44 of Set 9 | atbasar
# Processing Record 45 of Set 9 | pingliang
# Processing Record 46 of Set 9 | lethem
# Processing Record 47 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 48 of Set 9 | skjervoy
# Processing Record 49 of Set 9 | mercedes
# Processing Record 50 of Set 9 | tremedal
# Processing Record 1 of Set 10 | maralal
# Processing Record 2 of Set 10 | pushkino
# Processing Record 3 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 10 | bukachacha
# Processing Record 5 of Set 10 | abilene
# Processing Record 6 of Set 10 | kiama
# Processing Record 7 of Set 10 | kailasahar
# City not found. Skipping...
# Processing Record 8 of Set 10 | eldikan
# City not found. Skipping...
# Processing Record 9 of Set 10 | huanren
# Processing Record 10 of Set 10 | florianopolis
# Processing Record 11 of Set 10 | angoram
# Processing Record 12 of Set 10 | los algarrobos
# Processing Record 13 of Set 10 | lewisporte
# Processing Record 14 of Set 10 | howick
# Processing Record 15 of Set 10 | ugoofaaru
# Processing Record 16 of Set 10 | nicseni
# Processing Record 17 of Set 10 | jasdan
# Processing Record 18 of Set 10 | nyurba
# Processing Record 19 of Set 10 | araouane
# Processing Record 20 of Set 10 | cabot
# Processing Record 21 of Set 10 | sembakung
# Processing Record 22 of Set 10 | asosa
# Processing Record 23 of Set 10 | gaya
# Processing Record 24 of Set 10 | soddy-daisy
# Processing Record 25 of Set 10 | lulea
# Processing Record 26 of Set 10 | azangaro
# Processing Record 27 of Set 10 | cao bang
# Processing Record 28 of Set 10 | caorle
# Processing Record 29 of Set 10 | kaeo
# Processing Record 30 of Set 10 | emerald
# Processing Record 31 of Set 10 | madimba
# Processing Record 32 of Set 10 | grand gaube
# Processing Record 33 of Set 10 | dhidhdhoo
# Processing Record 34 of Set 10 | sakakah
# Processing Record 35 of Set 10 | khandyga
# Processing Record 36 of Set 10 | okulovka
# Processing Record 37 of Set 10 | dicabisagan
# Processing Record 38 of Set 10 | hervey bay
# Processing Record 39 of Set 10 | alofi
# Processing Record 40 of Set 10 | coari
# Processing Record 41 of Set 10 | rolim de moura
# City not found. Skipping...
# Processing Record 42 of Set 10 | bay roberts
# Processing Record 43 of Set 10 | makakilo city
# Processing Record 44 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 45 of Set 10 | malatya
# Processing Record 46 of Set 10 | killybegs
# Processing Record 47 of Set 10 | balugaon
# Processing Record 48 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 49 of Set 10 | adrar
# Processing Record 50 of Set 10 | rio blanco
# Processing Record 1 of Set 11 | ganzhou
# Processing Record 2 of Set 11 | akureyri
# Processing Record 3 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 4 of Set 11 | naliya
# Processing Record 5 of Set 11 | amga
# Processing Record 6 of Set 11 | aksu
# Processing Record 7 of Set 11 | menongue
# Processing Record 8 of Set 11 | praia da vitoria
# Processing Record 9 of Set 11 | bapatla
# Processing Record 10 of Set 11 | morgan city
# Processing Record 11 of Set 11 | wewak
# Processing Record 12 of Set 11 | deputatskiy
# Processing Record 13 of Set 11 | vermilion
# Processing Record 14 of Set 11 | daru
# Processing Record 15 of Set 11 | kendari
# Processing Record 16 of Set 11 | port-gentil
# Processing Record 17 of Set 11 | barra
# Processing Record 18 of Set 11 | narsaq
# Processing Record 19 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 20 of Set 11 | sungaipenuh
# Processing Record 21 of Set 11 | calama
# Processing Record 22 of Set 11 | tabora
# Processing Record 23 of Set 11 | kemijarvi
# Processing Record 24 of Set 11 | chifeng
# Processing Record 25 of Set 11 | malanje
# Processing Record 26 of Set 11 | clarence town
# Processing Record 27 of Set 11 | santa cruz cabralia
# Processing Record 28 of Set 11 | champerico
# Processing Record 29 of Set 11 | tokur
# Processing Record 30 of Set 11 | shchelyayur
# City not found. Skipping...
# Processing Record 31 of Set 11 | dargaville
# Processing Record 32 of Set 11 | vilhena
# Processing Record 33 of Set 11 | laguna
# Processing Record 34 of Set 11 | bengbu
# Processing Record 35 of Set 11 | rolla
# Processing Record 36 of Set 11 | maturin
# Processing Record 37 of Set 11 | coquimbo
# Processing Record 38 of Set 11 | khani
# Processing Record 39 of Set 11 | neiafu
# Processing Record 40 of Set 11 | ningyang
# Processing Record 41 of Set 11 | daman
# Processing Record 42 of Set 11 | kupang
# Processing Record 43 of Set 11 | keetmanshoop
# Processing Record 44 of Set 11 | ust-kuyga
# Processing Record 45 of Set 11 | great bend
# Processing Record 46 of Set 11 | adiake
# Processing Record 47 of Set 11 | severo-yeniseyskiy
# Processing Record 48 of Set 11 | hay river
# Processing Record 49 of Set 11 | caravelas
# Processing Record 50 of Set 11 | wonthaggi
# Processing Record 1 of Set 12 | pilar
# Processing Record 2 of Set 12 | lorengau
# Processing Record 3 of Set 12 | bulgan
# Processing Record 4 of Set 12 | colon
# Processing Record 5 of Set 12 | svetlyy
# Processing Record 6 of Set 12 | northam
# Processing Record 7 of Set 12 | goderich
# Processing Record 8 of Set 12 | jalu
# Processing Record 9 of Set 12 | puerto del rosario
# Processing Record 10 of Set 12 | bilibino
# Processing Record 11 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 12 of Set 12 | merrill
# Processing Record 13 of Set 12 | mandalgovi
# Processing Record 14 of Set 12 | benavente
# Processing Record 15 of Set 12 | yemtsa
# Processing Record 16 of Set 12 | larsnes
# Processing Record 17 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 18 of Set 12 | kaa-khem
# Processing Record 19 of Set 12 | yulara
# Processing Record 20 of Set 12 | sitka
# Processing Record 21 of Set 12 | banda aceh
# Processing Record 22 of Set 12 | douentza
# Processing Record 23 of Set 12 | roebourne
# Processing Record 24 of Set 12 | yambio
# Processing Record 25 of Set 12 | wexford
# Processing Record 26 of Set 12 | mishan
# Processing Record 27 of Set 12 | gariaband
# Processing Record 28 of Set 12 | shelburne
# Processing Record 29 of Set 12 | carandai
# Processing Record 30 of Set 12 | volksrust
# Processing Record 31 of Set 12 | ilebo
# Processing Record 32 of Set 12 | sechura
# Processing Record 33 of Set 12 | galveston
# Processing Record 34 of Set 12 | aklavik
# Processing Record 35 of Set 12 | liberty
# Processing Record 36 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 37 of Set 12 | nkhotakota
# Processing Record 38 of Set 12 | sept-iles
# Processing Record 39 of Set 12 | naftah
# City not found. Skipping...
# Processing Record 40 of Set 12 | port arthur
# Processing Record 41 of Set 12 | broome
# Processing Record 42 of Set 12 | susangerd
# Processing Record 43 of Set 12 | dongsheng
# Processing Record 44 of Set 12 | saint-joseph
# Processing Record 45 of Set 12 | hamilton
# Processing Record 46 of Set 12 | sidi ali
# Processing Record 47 of Set 12 | kanye
# Processing Record 48 of Set 12 | tiznit
# Processing Record 49 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 50 of Set 12 | cove
# Processing Record 1 of Set 13 | guerrero negro
# Processing Record 2 of Set 13 | marawi
# Processing Record 3 of Set 13 | albion
# Processing Record 4 of Set 13 | bilma
# Processing Record 5 of Set 13 | lasem
# Processing Record 6 of Set 13 | sembe
# Processing Record 7 of Set 13 | erzin
# Processing Record 8 of Set 13 | pandan
# Processing Record 9 of Set 13 | sao lourenco do sul
# Processing Record 10 of Set 13 | koshki
# Processing Record 11 of Set 13 | asyut
# Processing Record 12 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 13 of Set 13 | kampot
# Processing Record 14 of Set 13 | koslan
# Processing Record 15 of Set 13 | savinka
# Processing Record 16 of Set 13 | kaduna
# Processing Record 17 of Set 13 | dunedin
# Processing Record 18 of Set 13 | batavia
# Processing Record 19 of Set 13 | pacho
# Processing Record 20 of Set 13 | phra phutthabat
# Processing Record 21 of Set 13 | okhotsk
# Processing Record 22 of Set 13 | port macquarie
# Processing Record 23 of Set 13 | nishihara
# Processing Record 24 of Set 13 | kushiro
# Processing Record 25 of Set 13 | praya
# Processing Record 26 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 13 | komsomolskiy
# Processing Record 28 of Set 13 | bury saint edmunds
# City not found. Skipping...
# Processing Record 29 of Set 13 | westport
# Processing Record 30 of Set 13 | mitsamiouli
# Processing Record 31 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 13 | vangaindrano
# Processing Record 33 of Set 13 | souillac
# Processing Record 34 of Set 13 | avera
# Processing Record 35 of Set 13 | manfredonia
# Processing Record 36 of Set 13 | bac lieu
# Processing Record 37 of Set 13 | zyryanka
# Processing Record 38 of Set 13 | vanavara
# Processing Record 39 of Set 13 | plaridel
# Processing Record 40 of Set 13 | alta floresta
# Processing Record 41 of Set 13 | olga
# Processing Record 42 of Set 13 | port augusta
# Processing Record 43 of Set 13 | dolgorukovo
# Processing Record 44 of Set 13 | kota bahru
# Processing Record 45 of Set 13 | ajaccio
# Processing Record 46 of Set 13 | caucaia
# Processing Record 47 of Set 13 | steamboat springs
# Processing Record 48 of Set 13 | tocopilla
# Processing Record 49 of Set 13 | cuenca
# Processing Record 50 of Set 13 | hami
# Processing Record 1 of Set 14 | blankenberge
# Processing Record 2 of Set 14 | mantua
# Processing Record 3 of Set 14 | kalengwa
# Processing Record 4 of Set 14 | kapoeta
# Processing Record 5 of Set 14 | dalvik
# Processing Record 6 of Set 14 | caraballeda
# Processing Record 7 of Set 14 | takoradi
# Processing Record 8 of Set 14 | freeport
# Processing Record 9 of Set 14 | payson
# Processing Record 10 of Set 14 | barrhead
# Processing Record 11 of Set 14 | marsa matruh
# Processing Record 12 of Set 14 | prince rupert
# Processing Record 13 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 14 | bom jesus
# Processing Record 15 of Set 14 | puerto escondido
# Processing Record 16 of Set 14 | tamala
# Processing Record 17 of Set 14 | kijang
# Processing Record 18 of Set 14 | senador jose porfirio
# Processing Record 19 of Set 14 | paramonga
# Processing Record 20 of Set 14 | pagudpud
# Processing Record 21 of Set 14 | teknaf
# Processing Record 22 of Set 14 | ofunato
# Processing Record 23 of Set 14 | santa fe
# Processing Record 24 of Set 14 | olinda
# Processing Record 25 of Set 14 | richards bay
# Processing Record 26 of Set 14 | zhuanghe
# Processing Record 27 of Set 14 | chadan
# Processing Record 28 of Set 14 | tiksi
# Processing Record 29 of Set 14 | okha
# Processing Record 30 of Set 14 | ewing
# Processing Record 31 of Set 14 | khorramshahr
# Processing Record 32 of Set 14 | ito
# Processing Record 33 of Set 14 | tabou
# Processing Record 34 of Set 14 | narasapur
# Processing Record 35 of Set 14 | dinguiraye
# Processing Record 36 of Set 14 | port lincoln
# Processing Record 37 of Set 14 | sola
# Processing Record 38 of Set 14 | lerwick
# Processing Record 39 of Set 14 | minden
# Processing Record 40 of Set 14 | lima
# Processing Record 41 of Set 14 | brindisi
# Processing Record 42 of Set 14 | kapit
# Processing Record 43 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 44 of Set 14 | mto wa mbu
# Processing Record 45 of Set 14 | krasnoselkup
# Processing Record 46 of Set 14 | saint-augustin
# Processing Record 47 of Set 14 | palmerston
# Processing Record 48 of Set 14 | yuanping
# Processing Record 49 of Set 14 | gunzburg
# Processing Record 50 of Set 14 | egvekinot
# Processing Record 1 of Set 15 | pafos
# Processing Record 2 of Set 15 | mahanoro
# Processing Record 3 of Set 15 | bonthe
# Processing Record 4 of Set 15 | mariental
# Processing Record 5 of Set 15 | ucluelet
# Processing Record 6 of Set 15 | nuuk
# Processing Record 7 of Set 15 | mae sai
# Processing Record 8 of Set 15 | okato
# Processing Record 9 of Set 15 | natal
# Processing Record 10 of Set 15 | thunder bay
# Processing Record 11 of Set 15 | marathon
# Processing Record 12 of Set 15 | kawana waters
# City not found. Skipping...
# Processing Record 13 of Set 15 | carndonagh
# Processing Record 14 of Set 15 | galle
# Processing Record 15 of Set 15 | muqui
# Processing Record 16 of Set 15 | lichuan
# Processing Record 17 of Set 15 | black river
# Processing Record 18 of Set 15 | jurm
# Processing Record 19 of Set 15 | manzhouli
# Processing Record 20 of Set 15 | potosi
# Processing Record 21 of Set 15 | moerai
# Processing Record 22 of Set 15 | edgewater
# Processing Record 23 of Set 15 | hluti
# Processing Record 24 of Set 15 | novikovo
# Processing Record 25 of Set 15 | isla vista
# Processing Record 26 of Set 15 | canutama
# Processing Record 27 of Set 15 | numan
# Processing Record 28 of Set 15 | vikhorevka
# Processing Record 29 of Set 15 | ponnani
# Processing Record 30 of Set 15 | salinas
# Processing Record 31 of Set 15 | kavaratti
# Processing Record 32 of Set 15 | tautira
# Processing Record 33 of Set 15 | shimoda
# Processing Record 34 of Set 15 | tottori
# Processing Record 35 of Set 15 | altona
# Processing Record 36 of Set 15 | garowe
# Processing Record 37 of Set 15 | kutum
# Processing Record 38 of Set 15 | caracoli
# Processing Record 39 of Set 15 | hvolsvollur
# Processing Record 40 of Set 15 | kulhudhuffushi
# Processing Record 41 of Set 15 | balsta
# Processing Record 42 of Set 15 | zhovti vody
# Processing Record 43 of Set 15 | aktas
# Processing Record 44 of Set 15 | opuwo
# Processing Record 45 of Set 15 | bairiki
# Processing Record 46 of Set 15 | sioux lookout
# Processing Record 47 of Set 15 | sur
# Processing Record 48 of Set 15 | burica
# City not found. Skipping...
# Processing Record 49 of Set 15 | vaasa
# Processing Record 50 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 1 of Set 16 | altamira
# Processing Record 2 of Set 16 | howell
# Processing Record 3 of Set 16 | pitimbu
# Processing Record 4 of Set 16 | uzhhorod
# Processing Record 5 of Set 16 | brest
# Processing Record 6 of Set 16 | heinola
# Processing Record 7 of Set 16 | simbahan
# Processing Record 8 of Set 16 | funtua
# Processing Record 9 of Set 16 | avila
# Processing Record 10 of Set 16 | rafsanjan
# Processing Record 11 of Set 16 | sault sainte marie
# Processing Record 12 of Set 16 | caluquembe
# Processing Record 13 of Set 16 | sehwan
# Processing Record 14 of Set 16 | banjarmasin
# Processing Record 15 of Set 16 | pangai
# Processing Record 16 of Set 16 | cheney
# Processing Record 17 of Set 16 | porto torres
# Processing Record 18 of Set 16 | tumannyy
# City not found. Skipping...
# Processing Record 19 of Set 16 | paragominas
# Processing Record 20 of Set 16 | panguna
# Processing Record 21 of Set 16 | hukuntsi
# Processing Record 22 of Set 16 | teya
# Processing Record 23 of Set 16 | kizukuri
# Processing Record 24 of Set 16 | kieta
# Processing Record 25 of Set 16 | ratnagiri
# Processing Record 26 of Set 16 | ambulu
# Processing Record 27 of Set 16 | bagdarin
# Processing Record 28 of Set 16 | payakumbuh
# Processing Record 29 of Set 16 | morant bay
# Processing Record 30 of Set 16 | santa ana
# Processing Record 31 of Set 16 | cheuskiny
# City not found. Skipping...
# Processing Record 32 of Set 16 | puro
# Processing Record 33 of Set 16 | suhbaatar
# Processing Record 34 of Set 16 | belomorsk
# Processing Record 35 of Set 16 | abu jubayhah
# City not found. Skipping...
# Processing Record 36 of Set 16 | gat
# Processing Record 37 of Set 16 | key largo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Save the new DataFrame as a CSV file
challenge_city_data_df = pd.DataFrame(city_data)
challenge_city_data_df.head(10)
# Out:
#                        City Country      Lat       Lng  Max Temp  Humidity  \
# 0          Pontal Do Parana      BR -25.6533  -48.5128     72.99        56
# 1                   Rikitea      PF -23.1203 -134.9692     71.55        85
# 2                  Katsuura      JP  35.1333  140.3000     66.88        78
# 3                   Margate      GB  51.3813    1.3862     62.69        73
# 4                     Bluff      NZ -46.6000  168.3333     45.81        74
# 5                    Torbay      CA  47.6666  -52.7314     50.54        73
# 6  Sao Domingos Do Maranhao      BR  -5.5758  -44.3853     73.94        83
# 7                Oranjestad      AW  12.5240  -70.0270     85.95        70
# 8                 Namatanai      PG  -3.6667  152.4333     78.67        80
# 9                     Moron      AR -34.6534  -58.6198     64.94        58
#
#    Cloudiness  Wind Speed Current Description
# 0           0        6.26           clear sky
# 1         100        5.35       moderate rain
# 2         100       13.91     overcast clouds
# 3          54        4.00       broken clouds
# 4          85       32.73     overcast clouds
# 5          68        7.07       broken clouds
# 6          98        5.82     overcast clouds
# 7          40       24.16    scattered clouds
# 8          31        5.01    scattered clouds
# 9          11        7.78          few clouds

# %%
output_data_file = "WeatherPy_Database.csv"
challenge_city_data_df.to_csv(output_data_file, index_label="City_ID")
